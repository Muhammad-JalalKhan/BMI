# %% [markdown]
# <a href="https://colab.research.google.com/github/Muhammad-JalalKhan/BMI/blob/main/Used_car_Dataset_Org.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
df = pd.read_csv('/content/used_car_dataset.csv')
df.head()
# Out:
#            Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0          Honda       City  2001   23    98,000 km       Manual  second
# 1         Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2     Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3  Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4  Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
#
#   FuelType PostedDate                                       AdditionInfo  \
# 0   Petrol     Nov-24  Honda City v teck in mint condition, valid gen...
# 1   Diesel     Jul-24  Toyota Innova 2.5 G (Diesel) 7 Seater, 2009, D...
# 2   Diesel     Nov-24  Volkswagen Vento 2010-2013 Diesel Breeze, 2010...
# 3   Diesel     Nov-24     Maruti Suzuki Swift 2017 Diesel Good Condition
# 4   Petrol     Nov-24       Maruti Suzuki Baleno Alpha CVT, 2019, Petrol
#
#      AskPrice
# 0  ₹ 1,95,000
# 1  ₹ 3,75,000
# 2  ₹ 1,84,999
# 3  ₹ 5,65,000
# ...

# %% [markdown]
# ## Clean Data

# %%
df.fillna(0, inplace=True)
print(df.info())
print(df.isnull().sum())
df = df.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9582 entries, 0 to 9581
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Brand         9582 non-null   object
#  1   model         9582 non-null   object
#  2   Year          9582 non-null   int64
#  3   Age           9582 non-null   int64
#  4   kmDriven      9582 non-null   object
#  5   Transmission  9582 non-null   object
#  6   Owner         9582 non-null   object
#  7   FuelType      9582 non-null   object
#  8   PostedDate    9582 non-null   object
#  9   AdditionInfo  9582 non-null   object
#  10  AskPrice      9582 non-null   object
# dtypes: int64(2), object(9)
# memory usage: 823.6+ KB
# None
# Brand           0
# model           0
# Year            0
# Age             0
# kmDriven        0
# Transmission    0
# Owner           0
# FuelType        0
# PostedDate      0
# AdditionInfo    0
# AskPrice        0
# dtype: int64

# %% [markdown]
# ## Analyze The Dataset

# %%
df.describe()  # Get summary statistics
print(df.describe())
# Out:
#               Year          Age
# count  9582.000000  9582.000000
# mean   2016.361094     7.638906
# std       4.087226     4.087226
# min    1986.000000     0.000000
# 25%    2014.000000     5.000000
# 50%    2017.000000     7.000000
# 75%    2019.000000    10.000000
# max    2024.000000    38.000000

# %% [markdown]
# ## Visualize The Data in Charts

# %% [markdown]
# ### Basic Visualization

# %%
import matplotlib.pyplot as plt

# Line plot
plt.plot(df['Year'], df['AskPrice'], marker='o')
plt.title("Line Plot")
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.show()

import matplotlib.pyplot as plt

# Line plot
plt.plot(df['Age'], df['FuelType'], marker='o')
plt.title("Line Plot")
plt.xlabel("X-axis Label")
plt.ylabel("Y-axis Label")
plt.show()

# %% [markdown]
# ### Visualization Through Histogram

# %%
# Histogram
plt.hist(df['Year'], bins=20, color='indigo', edgecolor='black')
plt.title("Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# Histogram
plt.hist(df['Age'], bins=20, color='indigo', edgecolor='black')
plt.title("Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ## Advanced visualization

# %% [markdown]
# ### Pair Plot Visualization

# %%
import seaborn as sns

# Pair plot
sns.pairplot(df, hue='Brand')  # Color by a categorical variable
plt.show()

sns.pairplot(df, hue='Owner')  # Color by a categorical variable
plt.show()

# %% [markdown]
# ## Interactive Visualization

# %% [markdown]
# ### Scatter Plot Visualization

# %%
import plotly.express as px

# Interactive scatter plot
fig = px.scatter(df, x='model', y='Age', color='model', title="Interactive Scatter Plot")
fig.show()
import plotly.express as px

# Interactive scatter plot
fig = px.scatter(df, x='PostedDate', y='Year', color='PostedDate', title="Interactive Scatter Plot")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Build AI Model

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Data separation as X & Y

# %%
y=df['AskPrice']
y
# Out:
# 0        ₹ 1,95,000
# 1        ₹ 3,75,000
# 2        ₹ 1,84,999
# 3        ₹ 5,65,000
# 4        ₹ 6,85,000
#            ...
# 9577    ₹ 10,40,000
# 9578     ₹ 3,75,000
# 9579     ₹ 4,15,000
# 9580     ₹ 8,55,000
# 9581     ₹ 6,99,000
# Name: AskPrice, Length: 9582, dtype: object

# %%
x=df.drop('AskPrice',axis=1)
x
# Out:
#               Brand      model  Year  Age     kmDriven Transmission   Owner  \
# 0             Honda       City  2001   23    98,000 km       Manual  second
# 1            Toyota     Innova  2009   15  190000.0 km       Manual  second
# 2        Volkswagen  VentoTest  2010   14    77,246 km       Manual   first
# 3     Maruti Suzuki      Swift  2017    7    83,500 km       Manual  second
# 4     Maruti Suzuki     Baleno  2019    5    45,000 km    Automatic   first
# ...             ...        ...   ...  ...          ...          ...     ...
# 9577          Skoda    Octavia  2014   10   105,904 km    Automatic  second
# 9578  Maruti Suzuki   Alto-800  2020    4    55,000 km       Manual   first
# 9579  Maruti Suzuki       Ritz  2013   11    92,000 km       Manual   first
# 9580        Hyundai      Verna  2019    5    72,000 km    Automatic   first
# 9581        Hyundai    New i20  2021    3    83,228 km       Manual  second
#
# ...

# %% [markdown]
# ### Data Splitting

# %%
import sklearn
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
#80% data is split in training set
x_train= pd.get_dummies(x_train, drop_first=True)
x_train
# Out:
#       Year  Age  Brand_Ashok  Brand_Aston Martin  Brand_Audi  Brand_BMW  \
# 2266  2015    9        False               False        True      False
# 4534  2016    8        False               False       False      False
# 1010  2020    4        False               False       False      False
# 8918  2017    7        False               False       False      False
# 1189  2018    6        False               False       False      False
# ...    ...  ...          ...                 ...         ...        ...
# 350   2015    9        False               False       False      False
# 79    2016    8        False               False       False      False
# 8039  2013   11        False               False       False      False
# 6936  2017    7        False               False       False      False
# 5640  2012   12        False               False       False      False
#
#       Brand_Bajaj  Brand_Bentley  Brand_Chevrolet  Brand_Datsun  ...  \
# ...

# %%
# 20% data is split in testing set
x_test
# Out:
#               Brand      model  Year  Age    kmDriven Transmission   Owner  \
# 3057  Mercedes-Benz  GLE Class  2017    7   59,000 km    Automatic  second
# 7660  Maruti Suzuki    Wagon-R  2015    9   85,000 km       Manual   first
# 6052         Toyota   Fortuner  2019    5  150,000 km    Automatic   first
# 8969     Volkswagen       Polo  2013   11   69,000 km       Manual  second
# 5713          Skoda      Rapid  2013   11   85,000 km       Manual  second
# ...             ...        ...   ...  ...         ...          ...     ...
# 7719       Mahindra     XUV500  2017    7  118,000 km    Automatic  second
# 9360        Hyundai        i20  2013   11   68,000 km       Manual  second
# 5740           Tata      Tiago  2018    6   43,000 km    Automatic   first
# 8988  Maruti Suzuki   Alto-800  2018    6   50,450 km       Manual   first
# 1111          Honda       Jazz  2016    8   46,000 km    Automatic  second
#
# ...

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Linear Regression Model

# %%
from sklearn .linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-bf8b0b66b8cd> in <cell line: 3>()
#       1 from sklearn .linear_model import LinearRegression
#       2 lr=LinearRegression()
# ----> 3 lr.fit(x_train,y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_base.py in fit(self, X, y, sample_weight)
#     607         accept_sparse = False if self.positive else ["csr", "csc", "coo"]
#     608
# --> 609         X, y = self._validate_data(
#     610             X,
#     611             y,
#
# ...
